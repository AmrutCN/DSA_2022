# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# from statsmodels.stats.weightstats import ztest

# %% [markdown]
# 1. Read the data into python

# %%
data = pd.read_csv (r'C:\Users\ADAM\Downloads\week10.csv')
df = pd.DataFrame(data, columns= ['ph','Hardness','Solids','Chloramines','Sulfate','Conductivity','Organic_carbon','Trihalomethanes','Turbidity'])
df
# Out:
#              ph    Hardness       Solids  Chloramines     Sulfate  \
# 0      8.316766  214.373394  22018.41744     8.059332  356.886136
# 1      9.092223  181.101509  17978.98634     6.546600  310.135738
# 2      5.584087  188.313324  28748.68774     7.544869  326.678363
# 3     10.223862  248.071735  28749.71654     7.513408  393.663395
# 4      8.635849  203.361523  13672.09176     4.563009  303.309771
# ...         ...         ...          ...          ...         ...
# 2006   8.989900  215.047358  15921.41202     6.297312  312.931021
# 2007   6.702547  207.321086  17246.92035     7.708117  304.510230
# 2008  11.491011   94.812545  37188.82602     9.263166  258.930600
# 2009   6.069616  186.659040  26138.78019     7.747547  345.700257
# 2010   4.668102  193.681736  47580.99160     7.166639  359.948574
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       363.266516       18.436525       100.341674   4.628771
# ...

# %% [markdown]
# 2. Check for null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2011 non-null   float64
#  1   Hardness         2011 non-null   float64
#  2   Solids           2011 non-null   float64
#  3   Chloramines      2011 non-null   float64
#  4   Sulfate          2011 non-null   float64
#  5   Conductivity     2011 non-null   float64
#  6   Organic_carbon   2011 non-null   float64
#  7   Trihalomethanes  2011 non-null   float64
#  8   Turbidity        2011 non-null   float64
# dtypes: float64(9)
# memory usage: 141.5 KB

# %%
df.isna().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# dtype: int64

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2011.000000  2011.000000   2011.000000  2011.000000  2011.000000
# mean      7.085990   195.968072  21917.441375     7.134338   333.224672
# std       1.573337    32.635085   8642.239815     1.584820    41.205172
# min       0.227499    73.492234    320.942611     1.390871   129.000000
# 25%       6.089723   176.744938  15615.665390     6.138895   307.632511
# 50%       7.027297   197.191839  20933.512750     7.143907   332.232177
# 75%       8.052969   216.441070  27182.587065     8.109726   359.330555
# max      14.000000   317.338124  56488.672410    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity
# count   2011.000000     2011.000000      2011.000000  2011.000000
# mean     426.526409       14.357709        66.400859     3.969729
# std       80.712572        3.324959        16.077109     0.780346
# ...

# %% [markdown]
# 3. Examine the variables ‘Hardness’, ‘Sulfate’, and ‘Organic_carbon’ and
# comment on your observations.

# %%
r = np.corrcoef(df['Hardness'], df['Organic_carbon'])
r
# Out:
# array([[1.        , 0.01322386],
#        [0.01322386, 1.        ]])

# %%
v=df[['Hardness', 'Organic_carbon']].dropna()
v.corr()
# Out:
#                 Hardness  Organic_carbon
# Hardness        1.000000        0.013224
# Organic_carbon  0.013224        1.000000

# %%
x=df.sort_values(['Hardness','Organic_carbon'])
plt.plot( x['Hardness'], x['Organic_carbon'])
plt.xlabel("Hardness")
plt.ylabel("Organic carbon")
plt.grid()
plt.show()
x
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 236    9.443359   73.492234  20438.224690     8.024953  315.805659
# 198   11.301794   77.459586  39227.619460     8.517986  337.501247
# 176   10.761898   81.710895  25999.953670     8.477394  318.427241
# 208   10.026224   94.091307  25510.097300     6.614114  385.402660
# 2008  11.491011   94.812545  37188.826020     9.263166  258.930600
# ...         ...         ...           ...          ...         ...
# 1615  10.188433  286.567991   7105.800709     9.840540  321.686059
# 1976   5.859822  287.975540   3640.734320     4.072626  391.697385
# 49    10.155440  300.292476  12652.362980     6.655126  398.647786
# 913    6.792407  306.627481  28508.216930     6.811416  293.078305
# 1754   9.318614  317.338124  24497.873940     7.597452  357.167217
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 236     458.677232       12.538681        50.852470   3.486646
# ...

# %%
y=df.sort_values(['Sulfate','Hardness'])
plt.plot( y['Sulfate'], y['Hardness'], '-r')
plt.xlabel("Sulfate")
plt.ylabel("Hardness")
plt.grid()
plt.show()
y
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 955   8.942046  215.673786  56488.672410     3.231438  129.000000
# 174   5.324942  280.089655  35344.658050    13.043806  180.206746
# 218   8.848586  188.919983  32033.332020    13.127000  182.397370
# 156   6.800119  242.008082  39143.403330     9.501695  187.170714
# 228   4.788861  234.893703  28174.620520    10.850036  187.424131
# ...        ...         ...           ...          ...         ...
# 1089  8.518532  128.263466  32018.289630     6.058740  458.441072
# 1072  8.895574  107.383327  27622.746270     6.163320  460.107069
# 942   7.381758  203.460302   1372.091043    11.129154  475.737460
# 988   7.445189  150.775723   4168.196994    10.573403  476.539717
# 1417  5.057736  137.689344  11229.137780     6.411410  481.030642
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 955     541.915468        9.313771        70.828374   4.354288
# ...

# %%
z=df.sort_values(['Sulfate','Organic_carbon'])
plt.plot(z['Sulfate'],z['Organic_carbon'], '-g')
plt.xlabel("Sulfate")
plt.ylabel("Organic carbon")
plt.grid()
plt.show()
z
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 955   8.942046  215.673786  56488.672410     3.231438  129.000000
# 174   5.324942  280.089655  35344.658050    13.043806  180.206746
# 218   8.848586  188.919983  32033.332020    13.127000  182.397370
# 156   6.800119  242.008082  39143.403330     9.501695  187.170714
# 228   4.788861  234.893703  28174.620520    10.850036  187.424131
# ...        ...         ...           ...          ...         ...
# 1089  8.518532  128.263466  32018.289630     6.058740  458.441072
# 1072  8.895574  107.383327  27622.746270     6.163320  460.107069
# 942   7.381758  203.460302   1372.091043    11.129154  475.737460
# 988   7.445189  150.775723   4168.196994    10.573403  476.539717
# 1417  5.057736  137.689344  11229.137780     6.411410  481.030642
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 955     541.915468        9.313771        70.828374   4.354288
# ...

# %%
features1=list(['Hardness','Sulfate','Organic_carbon'])
df[features1].corr()
# Out:
#                 Hardness   Sulfate  Organic_carbon
# Hardness        1.000000 -0.108521        0.013224
# Sulfate        -0.108521  1.000000        0.026776
# Organic_carbon  0.013224  0.026776        1.000000

# %% [markdown]
# when sulfate increases hardness decreases
#
# when Organic_carbon increases hardness increases

# %% [markdown]
# 4. Carry out correlation analysis on the dataset and find the correlation factor
# between
#
# a. ph and Chloramines
#
# b. ph and Conductivity

# %%
from scipy.stats import pearsonr

# %%
features2=list(['ph','Chloramines'])
print(pearsonr(df['ph'], df['Chloramines']))
df[features2].corr()
# Out:
# (-0.024768491224521388, 0.2669118820828782)
#                    ph  Chloramines
# ph           1.000000    -0.024768
# Chloramines -0.024768     1.000000

# %%
features3=list(['ph','Conductivity'])
print(pearsonr(df['ph'], df['Conductivity']))
df[features3].corr()
# Out:
# (0.014127848401099352, 0.5266099779022468)
#                     ph  Conductivity
# ph            1.000000      0.014128
# Conductivity  0.014128      1.000000
